# %% [markdown]
# # Advenced Computer Vision

# %% [markdown]
# ## Camera Calibration

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
% matplotlib inline

# %%
# read the an image
# cal_img_path = "/home/yousof/SDC/DATA/chessboard/source"
cal_img_path = "images/chessboard/cal"
img = mpimg.imread (cal_img_path+"/DSC_0978.JPG")
# img = mpimg.imread (cal_img_path+"/chessboard.jpg")
plt.imshow(img)
plt.show()

# %%
# % matplotlib qt
objpoints=[]
imgpoints=[]

objp=np.zeros((7*7,3),np.float32)
objp[:,:2] = np.mgrid[0:7,0:7].T.reshape(-1,2)
# print(objp)

gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')
plt.show()

plt.figure()
gray_editted = cv2.blur(gray,(10,10))
gray_editted = (gray_editted>110)*255
gray_editted = 255-np.uint8(gray_editted)
plt.imshow(gray_editted,cmap='gray')
plt.show()

# %%
% matplotlib qt
ret, corners = cv2.findChessboardCorners(gray_editted,(7,7),None)
print("ret",ret)
# print("corners",corners)

if ret == True:
    imgpoints.append(corners)
    objpoints.append(objp)
    img = cv2.drawChessboardCorners(img, (7,7), corners, ret)

plt.imshow(img)
# Out:
# ret True

# %%
import glob
% matplotlib qt

images = glob.glob(cal_img_path + '/DSC_*.JPG')
print(len(images))

objpoints=[]
imgpoints=[]

objp=np.zeros((7*7,3),np.float32)
objp[:,:2] = np.mgrid[0:7,0:7].T.reshape(-1,2)

i = 1
for fname in images:
    img = mpimg.imread (fname)
    gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    gray_editted = cv2.blur(gray,(10,10))
    gray_editted = (gray_editted>110)*255
    gray_editted = 255-np.uint8(gray_editted)
    ret, corners = cv2.findChessboardCorners(gray_editted,(7,7))
    if ret == True:
        print(i , 'found!!!')
        i+=1
        imgpoints.append(corners)
        objpoints.append(objp)
        img = cv2.drawChessboardCorners(img, (7,7),corners,ret)
        plt.imshow(img)
        plt.show()
# Out:
# 27
# 1 found!!!
# 2 found!!!
# 3 found!!!
# 4 found!!!
# 5 found!!!
# 6 found!!!
# 7 found!!!
# 8 found!!!
# 9 found!!!
# 10 found!!!
# 11 found!!!
# 12 found!!!
# 13 found!!!
# 14 found!!!
# 15 found!!!
# 16 found!!!
# 17 found!!!
# 18 found!!!
# 19 found!!!
# 20 found!!!
# 21 found!!!
# 22 found!!!
# 23 found!!!
# 24 found!!!
# 25 found!!!
# 26 found!!!
# 27 found!!!

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
# print(ret, mtx, dist, rvecs, tvecs)

# %%
% matplotlib inline
img = mpimg.imread (images[8])
plt.figure()
plt.imshow(img)
dst = cv2.undistort(img, mtx, dist, None, mtx)
plt.figure()
plt.imshow(dst)
plt.show()
